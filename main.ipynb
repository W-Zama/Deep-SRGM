# %%
import pandas as pd
from logic.deep_srgm import run
from matplotlib import pyplot as plt

df = pd.read_csv('resources/example_datasets/J1.csv')
model, scaler_X, scaler_y = run(df[["time_interval"]], df[["number_of_failures"]], seed=1, num_of_epochs=1000, num_of_units_per_layer=300, learning_rate=.001, batch_size=2, log=None)

# model.eval()
# prediction = model(scaler_X.transform(df[["time_interval"]])).detach().numpy()
# Out:
# Epoch [100/1000], Train Loss: 0.6405
# Epoch [200/1000], Train Loss: 0.6125
# Epoch [300/1000], Train Loss: 0.6480
# Epoch [400/1000], Train Loss: 0.5946
# Epoch [500/1000], Train Loss: 0.5974
# Epoch [600/1000], Train Loss: 0.6227
# Epoch [700/1000], Train Loss: 0.5979
# Epoch [800/1000], Train Loss: 0.6154
# Epoch [900/1000], Train Loss: 0.6076
# Epoch [1000/1000], Train Loss: 0.5983
